# %%
import pandas as pd

import seaborn as sns

import matplotlib.pyplot as plt
import numpy as np
df = pd.read_csv('data_survey.csv')

# %% [markdown]
# # DATA SURVEY KELOMPOK 8

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 13 columns):
#  #   Column                                                                                            Non-Null Count  Dtype
# ---  ------                                                                                            --------------  -----
#  0   No                                                                                                500 non-null    int64
#  1   Seberapa seringkah anda menggunakan bahasa pemrograman C?                                         500 non-null    int64
#  2   Seberapa tahukah anda tentang bahasa permograman Java?                                            500 non-null    int64
#  3   Pernahkah anda membuat program menggunakan bahasa pemrograman Python?                             500 non-null    int64
#  4   Seberapa tahukah anda tentang Pemrograman Interface (API)?                                        500 non-null    int64
#  5   Seberapa tahukah anda tentang Pemrograman Berorientasi Objek (OOP)?                               500 non-null    int64
#  6   Seberapa seringkah anda menggunakan programming software bajakan?                                 500 non-null    int64
#  7   Seberapa perlunya dokumen manual/tutorial ketika membuat program?                                 500 non-null    int64
#  8   Pernakah anda melakukan trial dan error atau mengembangkan program yang dibuat orang lain?        500 non-null    int64
#  9   Seberapa tahukah anda menggunakan Extension saat membuat program?                                 500 non-null    int64
#  10  Seberapa seringkah anda mengelola (menginstal,menghapus,menonaktifkan instalasi) Extension anda?  500 non-null    int64
#  11   Apakah anda pernah menggunakan Extension berbayar?                                               500 non-null    int64
#  12   Apakah anda pernah menggunakan Auto Indent Extension?                                            500 non-null    int64
# dtypes: int64(13)
# memory usage: 50.9 KB

# %%
df.dtypes
# Out:
# No                                                                                                  int64
# Seberapa seringkah anda menggunakan bahasa pemrograman C?                                           int64
# Seberapa tahukah anda tentang bahasa permograman Java?                                              int64
# Pernahkah anda membuat program menggunakan bahasa pemrograman Python?                               int64
# Seberapa tahukah anda tentang Pemrograman Interface (API)?                                          int64
# Seberapa tahukah anda tentang Pemrograman Berorientasi Objek (OOP)?                                 int64
# Seberapa seringkah anda menggunakan programming software bajakan?                                   int64
# Seberapa perlunya dokumen manual/tutorial ketika membuat program?                                   int64
# Pernakah anda melakukan trial dan error atau mengembangkan program yang dibuat orang lain?          int64
# Seberapa tahukah anda menggunakan Extension saat membuat program?                                   int64
# Seberapa seringkah anda mengelola (menginstal,menghapus,menonaktifkan instalasi) Extension anda?    int64
#  Apakah anda pernah menggunakan Extension berbayar?                                                 int64
#  Apakah anda pernah menggunakan Auto Indent Extension?                                              int64
# dtype: object

# %% [markdown]
# ## Data Awal Tabel

# %%
df.head(6)
# Out:
#    No  Seberapa seringkah anda menggunakan bahasa pemrograman C?  \
# 0   1                                                  1
# 1   2                                                  1
# 2   3                                                  1
# 3   4                                                  4
# 4   5                                                  3
# 5   6                                                  1
#
#    Seberapa tahukah anda tentang bahasa permograman Java?  \
# 0                                                  2
# 1                                                  2
# 2                                                  2
# 3                                                  2
# 4                                                  2
# 5                                                  2
#
#    Pernahkah anda membuat program menggunakan bahasa pemrograman Python?  \
# 0                                                  2
# 1                                                  2
# 2                                                  1
# 3                                                  1
# 4                                                  1
# 5                                                  2
#
#    Seberapa tahukah anda tentang Pemrograman Interface (API)?  \
# 0                                                  1
# 1                                                  1
# 2                                                  3
# 3                                                  2
# 4                                                  1
# 5                                                  2
#
#    Seberapa tahukah anda tentang Pemrograman Berorientasi Objek (OOP)?  \
# 0                                                  1
# 1                                                  1
# 2                                                  2
# 3                                                  2
# 4                                                  1
# 5                                                  4
#
#    Seberapa seringkah anda menggunakan programming software bajakan?  \
# 0                                                  3
# 1                                                  3
# 2                                                  1
# 3                                                  1
# 4                                                  1
# 5                                                  2
#
#    Seberapa perlunya dokumen manual/tutorial ketika membuat program?  \
# 0                                                  5
# 1                                                  5
# 2                                                  4
# 3                                                  4
# 4                                                  1
# 5                                                  5
#
#    Pernakah anda melakukan trial dan error atau mengembangkan program yang dibuat orang lain?  \
# 0                                                  1
# 1                                                  1
# 2                                                  4
# 3                                                  1
# 4                                                  1
# 5                                                  4
#
#    Seberapa tahukah anda menggunakan Extension saat membuat program?  \
# 0                                                  1
# 1                                                  1
# 2                                                  3
# 3                                                  1
# 4                                                  1
# 5                                                  3
#
#    Seberapa seringkah anda mengelola (menginstal,menghapus,menonaktifkan instalasi) Extension anda?  \
# 0                                                  1
# 1                                                  1
# 2                                                  3
# 3                                                  3
# 4                                                  1
# 5                                                  1
#
#     Apakah anda pernah menggunakan Extension berbayar?  \
# 0                                                  1
# 1                                                  1
# 2                                                  1
# 3                                                  1
# 4                                                  1
# 5                                                  1
#
#     Apakah anda pernah menggunakan Auto Indent Extension?
# 0                                                  1
# 1                                                  1
# 2                                                  1
# 3                                                  1
# 4                                                  1
# 5                                                  1

# %% [markdown]
# ## Data Akhir Tabel

# %%
df.tail()
# Out:
#       No  Seberapa seringkah anda menggunakan bahasa pemrograman C?  \
# 495  496                                                  1
# 496  497                                                  1
# 497  498                                                  3
# 498  499                                                  1
# 499  500                                                  3
#
#      Seberapa tahukah anda tentang bahasa permograman Java?  \
# 495                                                  1
# 496                                                  1
# 497                                                  2
# 498                                                  1
# 499                                                  2
#
#      Pernahkah anda membuat program menggunakan bahasa pemrograman Python?  \
# 495                                                  1
# 496                                                  1
# 497                                                  2
# 498                                                  1
# 499                                                  1
#
#      Seberapa tahukah anda tentang Pemrograman Interface (API)?  \
# 495                                                  2
# 496                                                  1
# 497                                                  2
# 498                                                  1
# 499                                                  2
#
#      Seberapa tahukah anda tentang Pemrograman Berorientasi Objek (OOP)?  \
# 495                                                  2
# 496                                                  1
# 497                                                  2
# 498                                                  3
# 499                                                  3
#
#      Seberapa seringkah anda menggunakan programming software bajakan?  \
# 495                                                  2
# 496                                                  3
# 497                                                  4
# 498                                                  3
# 499                                                  3
#
#      Seberapa perlunya dokumen manual/tutorial ketika membuat program?  \
# 495                                                  2
# 496                                                  4
# 497                                                  5
# 498                                                  5
# 499                                                  5
#
#      Pernakah anda melakukan trial dan error atau mengembangkan program yang dibuat orang lain?  \
# 495                                                  1
# 496                                                  1
# 497                                                  2
# 498                                                  1
# 499                                                  1
#
#      Seberapa tahukah anda menggunakan Extension saat membuat program?  \
# 495                                                  1
# 496                                                  1
# 497                                                  1
# 498                                                  1
# 499                                                  1
#
#      Seberapa seringkah anda mengelola (menginstal,menghapus,menonaktifkan instalasi) Extension anda?  \
# 495                                                  1
# 496                                                  1
# 497                                                  1
# 498                                                  1
# 499                                                  1
#
#       Apakah anda pernah menggunakan Extension berbayar?  \
# 495                                                  1
# 496                                                  1
# 497                                                  1
# 498                                                  1
# 499                                                  1
#
#       Apakah anda pernah menggunakan Auto Indent Extension?
# 495                                                  1
# 496                                                  1
# 497                                                  1
# 498                                                  1
# 499                                                  1

# %% [markdown]
# ## Dimensi Data

# %%
df.shape
# Out:
# (12, 14)

# %% [markdown]
# ## Feature Yang Tersedia

# %%
df.columns
# Out:
# Index(['Nomor', 'Pilihan Jawaban',
#        'Seberapa sering anda menggunakan bahasa pemrograman C?',
#        'Seberapa tahukah anda tentang bahasa permograman Java?',
#        'Pernahkah anda membuat program menggunakan bahasa pemrograman Python?',
#        'Seberapa tahukah anda tentang Pemrograman Interface (API)?',
#        'Seberapa tahukah anda tentang Pemrograman Berorientasi Objek (OOP)?',
#        'Seberapa sering anda menggunakan programming software bajakan?',
#        'Seberapa perlunya dokumen manual/tutorial ketika membuat program?',
#        'Pernakah anda melakukan trial dan error atau mengembangkan program yang dibuat orang lain?',
#        'Seberapa seringkah anda menggunakan Extension saat membuat program?',
#        'Seberapa sering anda mengelola (menginstal,menghapus,menonaktifkan instalasi) Extension anda?',
#        ' Apakah anda sering menggunakan Extension berbayar?',
#        ' Apakah anda sering menggunakan Auto Indent Extension?'],
#       dtype='object')

# %% [markdown]
# ## Gambar Statistik Setiap Features

# %%
df.describe()
# Out:
#            Nomor  Seberapa sering anda menggunakan bahasa pemrograman C?  \
# count  12.000000                                          12.000000
# mean    6.500000                                          41.666667
# std     3.605551                                          71.891754
# min     1.000000                                           0.000000
# 25%     3.750000                                           0.000000
# 50%     6.500000                                           0.000000
# 75%     9.250000                                          47.500000
# max    12.000000                                         197.000000
#
#        Seberapa tahukah anda tentang bahasa permograman Java?  \
# count                                          12.000000
# mean                                           41.666667
# std                                            65.714719
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                            73.500000
# max                                           175.000000
#
#        Pernahkah anda membuat program menggunakan bahasa pemrograman Python?  \
# count                                          12.000000
# mean                                           41.666667
# std                                            98.466730
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                            33.250000
# max                                           346.000000
#
#        Seberapa tahukah anda tentang Pemrograman Interface (API)?  \
# count                                          12.000000
# mean                                           41.666667
# std                                            70.815167
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                            55.500000
# max                                           200.000000
#
#        Seberapa tahukah anda tentang Pemrograman Berorientasi Objek (OOP)?  \
# count                                          12.000000
# mean                                           41.666667
# std                                            67.606258
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                            65.500000
# max                                           196.000000
#
#        Seberapa sering anda menggunakan programming software bajakan?  \
# count                                          12.000000
# mean                                           41.666667
# std                                            66.935971
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                            63.750000
# max                                           208.000000
#
#        Seberapa perlunya dokumen manual/tutorial ketika membuat program?  \
# count                                          12.000000
# mean                                           41.666667
# std                                            67.681518
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                            48.750000
# max                                           187.000000
#
#        Pernakah anda melakukan trial dan error atau mengembangkan program yang dibuat orang lain?  \
# count                                          12.000000
# mean                                           41.666667
# std                                            83.732619
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                            39.000000
# max                                           291.000000
#
#        Seberapa seringkah anda menggunakan Extension saat membuat program?  \
# count                                          12.000000
# mean                                           41.666667
# std                                            82.992150
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                            29.750000
# max                                           274.000000
#
#        Seberapa sering anda mengelola (menginstal,menghapus,menonaktifkan instalasi) Extension anda?  \
# count                                          12.000000
# mean                                           41.666667
# std                                            75.443336
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                            39.750000
# max                                           238.000000
#
#         Apakah anda sering menggunakan Extension berbayar?  \
# count                                          12.000000
# mean                                           41.666667
# std                                            97.013901
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                            34.250000
# max                                           338.000000
#
#         Apakah anda sering menggunakan Auto Indent Extension?
# count                                          12.000000
# mean                                           41.666667
# std                                            97.109435
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                            32.000000
# max                                           338.000000

# %%
col_to_drop = ['Nomor']
df= df.drop(col_to_drop, axis=1)

# %% [markdown]
# ## Mean

# %%
print ("Mean :")
df.mean()
# Out:
# Mean :
# Seberapa sering anda menggunakan bahasa pemrograman C?                                           41.666667
# Seberapa tahukah anda tentang bahasa permograman Java?                                           41.666667
# Pernahkah anda membuat program menggunakan bahasa pemrograman Python?                            41.666667
# Seberapa tahukah anda tentang Pemrograman Interface (API)?                                       41.666667
# Seberapa tahukah anda tentang Pemrograman Berorientasi Objek (OOP)?                              41.666667
# Seberapa sering anda menggunakan programming software bajakan?                                   41.666667
# Seberapa perlunya dokumen manual/tutorial ketika membuat program?                                41.666667
# Pernakah anda melakukan trial dan error atau mengembangkan program yang dibuat orang lain?       41.666667
# Seberapa seringkah anda menggunakan Extension saat membuat program?                              41.666667
# Seberapa sering anda mengelola (menginstal,menghapus,menonaktifkan instalasi) Extension anda?    41.666667
#  Apakah anda sering menggunakan Extension berbayar?                                              41.666667
#  Apakah anda sering menggunakan Auto Indent Extension?                                           41.666667
# dtype: float64

# %% [markdown]
# ## Correlations

# %%
correlations = df.corr(method='kendall')
correlations
# Out:
#                                                     Seberapa sering anda menggunakan bahasa pemrograman C?  \
# Seberapa sering anda menggunakan bahasa pemrogr...                                           1.000000
# Seberapa tahukah anda tentang bahasa permograma...                                          -0.155556
# Pernahkah anda membuat program menggunakan baha...                                           0.955556
# Seberapa tahukah anda tentang Pemrograman Inter...                                          -0.111111
# Seberapa tahukah anda tentang Pemrograman Beror...                                          -0.111111
# Seberapa sering anda menggunakan programming so...                                           1.000000
# Seberapa perlunya dokumen manual/tutorial ketik...                                          -0.244444
# Pernakah anda melakukan trial dan error atau me...                                           0.955556
# Seberapa seringkah anda menggunakan Extension s...                                           1.000000
# Seberapa sering anda mengelola (menginstal,meng...                                           1.000000
#  Apakah anda sering menggunakan Extension berba...                                           0.955556
#  Apakah anda sering menggunakan Auto Indent Ext...                                           1.000000
#
#                                                     Seberapa tahukah anda tentang bahasa permograman Java?  \
# Seberapa sering anda menggunakan bahasa pemrogr...                                          -0.155556
# Seberapa tahukah anda tentang bahasa permograma...                                           1.000000
# Pernahkah anda membuat program menggunakan baha...                                          -0.155556
# Seberapa tahukah anda tentang Pemrograman Inter...                                           0.955556
# Seberapa tahukah anda tentang Pemrograman Beror...                                           0.955556
# Seberapa sering anda menggunakan programming so...                                          -0.155556
# Seberapa perlunya dokumen manual/tutorial ketik...                                          -0.044444
# Pernakah anda melakukan trial dan error atau me...                                          -0.155556
# Seberapa seringkah anda menggunakan Extension s...                                          -0.155556
# Seberapa sering anda mengelola (menginstal,meng...                                          -0.155556
#  Apakah anda sering menggunakan Extension berba...                                          -0.155556
#  Apakah anda sering menggunakan Auto Indent Ext...                                          -0.155556
#
#                                                     Pernahkah anda membuat program menggunakan bahasa pemrograman Python?  \
# Seberapa sering anda menggunakan bahasa pemrogr...                                           0.955556
# Seberapa tahukah anda tentang bahasa permograma...                                          -0.155556
# Pernahkah anda membuat program menggunakan baha...                                           1.000000
# Seberapa tahukah anda tentang Pemrograman Inter...                                          -0.111111
# Seberapa tahukah anda tentang Pemrograman Beror...                                          -0.111111
# Seberapa sering anda menggunakan programming so...                                           0.955556
# Seberapa perlunya dokumen manual/tutorial ketik...                                          -0.244444
# Pernakah anda melakukan trial dan error atau me...                                           0.911111
# Seberapa seringkah anda menggunakan Extension s...                                           0.955556
# Seberapa sering anda mengelola (menginstal,meng...                                           0.955556
#  Apakah anda sering menggunakan Extension berba...                                           1.000000
#  Apakah anda sering menggunakan Auto Indent Ext...                                           0.955556
#
#                                                     Seberapa tahukah anda tentang Pemrograman Interface (API)?  \
# Seberapa sering anda menggunakan bahasa pemrogr...                                          -0.111111
# Seberapa tahukah anda tentang bahasa permograma...                                           0.955556
# Pernahkah anda membuat program menggunakan baha...                                          -0.111111
# Seberapa tahukah anda tentang Pemrograman Inter...                                           1.000000
# Seberapa tahukah anda tentang Pemrograman Beror...                                           1.000000
# Seberapa sering anda menggunakan programming so...                                          -0.111111
# Seberapa perlunya dokumen manual/tutorial ketik...                                           0.000000
# Pernakah anda melakukan trial dan error atau me...                                          -0.111111
# Seberapa seringkah anda menggunakan Extension s...                                          -0.111111
# Seberapa sering anda mengelola (menginstal,meng...                                          -0.111111
#  Apakah anda sering menggunakan Extension berba...                                          -0.111111
#  Apakah anda sering menggunakan Auto Indent Ext...                                          -0.111111
#
#                                                     Seberapa tahukah anda tentang Pemrograman Berorientasi Objek (OOP)?  \
# Seberapa sering anda menggunakan bahasa pemrogr...                                          -0.111111
# Seberapa tahukah anda tentang bahasa permograma...                                           0.955556
# Pernahkah anda membuat program menggunakan baha...                                          -0.111111
# Seberapa tahukah anda tentang Pemrograman Inter...                                           1.000000
# Seberapa tahukah anda tentang Pemrograman Beror...                                           1.000000
# Seberapa sering anda menggunakan programming so...                                          -0.111111
# Seberapa perlunya dokumen manual/tutorial ketik...                                           0.000000
# Pernakah anda melakukan trial dan error atau me...                                          -0.111111
# Seberapa seringkah anda menggunakan Extension s...                                          -0.111111
# Seberapa sering anda mengelola (menginstal,meng...                                          -0.111111
#  Apakah anda sering menggunakan Extension berba...                                          -0.111111
#  Apakah anda sering menggunakan Auto Indent Ext...                                          -0.111111
#
#                                                     Seberapa sering anda menggunakan programming software bajakan?  \
# Seberapa sering anda menggunakan bahasa pemrogr...                                           1.000000
# Seberapa tahukah anda tentang bahasa permograma...                                          -0.155556
# Pernahkah anda membuat program menggunakan baha...                                           0.955556
# Seberapa tahukah anda tentang Pemrograman Inter...                                          -0.111111
# Seberapa tahukah anda tentang Pemrograman Beror...                                          -0.111111
# Seberapa sering anda menggunakan programming so...                                           1.000000
# Seberapa perlunya dokumen manual/tutorial ketik...                                          -0.244444
# Pernakah anda melakukan trial dan error atau me...                                           0.955556
# Seberapa seringkah anda menggunakan Extension s...                                           1.000000
# Seberapa sering anda mengelola (menginstal,meng...                                           1.000000
#  Apakah anda sering menggunakan Extension berba...                                           0.955556
#  Apakah anda sering menggunakan Auto Indent Ext...                                           1.000000
#
#                                                     Seberapa perlunya dokumen manual/tutorial ketika membuat program?  \
# Seberapa sering anda menggunakan bahasa pemrogr...                                          -0.244444
# Seberapa tahukah anda tentang bahasa permograma...                                          -0.044444
# Pernahkah anda membuat program menggunakan baha...                                          -0.244444
# Seberapa tahukah anda tentang Pemrograman Inter...                                           0.000000
# Seberapa tahukah anda tentang Pemrograman Beror...                                           0.000000
# Seberapa sering anda menggunakan programming so...                                          -0.244444
# Seberapa perlunya dokumen manual/tutorial ketik...                                           1.000000
# Pernakah anda melakukan trial dan error atau me...                                          -0.244444
# Seberapa seringkah anda menggunakan Extension s...                                          -0.244444
# Seberapa sering anda mengelola (menginstal,meng...                                          -0.244444
#  Apakah anda sering menggunakan Extension berba...                                          -0.244444
#  Apakah anda sering menggunakan Auto Indent Ext...                                          -0.244444
#
#                                                     Pernakah anda melakukan trial dan error atau mengembangkan program yang dibuat orang lain?  \
# Seberapa sering anda menggunakan bahasa pemrogr...                                           0.955556
# Seberapa tahukah anda tentang bahasa permograma...                                          -0.155556
# Pernahkah anda membuat program menggunakan baha...                                           0.911111
# Seberapa tahukah anda tentang Pemrograman Inter...                                          -0.111111
# Seberapa tahukah anda tentang Pemrograman Beror...                                          -0.111111
# Seberapa sering anda menggunakan programming so...                                           0.955556
# Seberapa perlunya dokumen manual/tutorial ketik...                                          -0.244444
# Pernakah anda melakukan trial dan error atau me...                                           1.000000
# Seberapa seringkah anda menggunakan Extension s...                                           0.955556
# Seberapa sering anda mengelola (menginstal,meng...                                           0.955556
#  Apakah anda sering menggunakan Extension berba...                                           0.911111
#  Apakah anda sering menggunakan Auto Indent Ext...                                           0.955556
#
#                                                     Seberapa seringkah anda menggunakan Extension saat membuat program?  \
# Seberapa sering anda menggunakan bahasa pemrogr...                                           1.000000
# Seberapa tahukah anda tentang bahasa permograma...                                          -0.155556
# Pernahkah anda membuat program menggunakan baha...                                           0.955556
# Seberapa tahukah anda tentang Pemrograman Inter...                                          -0.111111
# Seberapa tahukah anda tentang Pemrograman Beror...                                          -0.111111
# Seberapa sering anda menggunakan programming so...                                           1.000000
# Seberapa perlunya dokumen manual/tutorial ketik...                                          -0.244444
# Pernakah anda melakukan trial dan error atau me...                                           0.955556
# Seberapa seringkah anda menggunakan Extension s...                                           1.000000
# Seberapa sering anda mengelola (menginstal,meng...                                           1.000000
#  Apakah anda sering menggunakan Extension berba...                                           0.955556
#  Apakah anda sering menggunakan Auto Indent Ext...                                           1.000000
#
#                                                     Seberapa sering anda mengelola (menginstal,menghapus,menonaktifkan instalasi) Extension anda?  \
# Seberapa sering anda menggunakan bahasa pemrogr...                                           1.000000
# Seberapa tahukah anda tentang bahasa permograma...                                          -0.155556
# Pernahkah anda membuat program menggunakan baha...                                           0.955556
# Seberapa tahukah anda tentang Pemrograman Inter...                                          -0.111111
# Seberapa tahukah anda tentang Pemrograman Beror...                                          -0.111111
# Seberapa sering anda menggunakan programming so...                                           1.000000
# Seberapa perlunya dokumen manual/tutorial ketik...                                          -0.244444
# Pernakah anda melakukan trial dan error atau me...                                           0.955556
# Seberapa seringkah anda menggunakan Extension s...                                           1.000000
# Seberapa sering anda mengelola (menginstal,meng...                                           1.000000
#  Apakah anda sering menggunakan Extension berba...                                           0.955556
#  Apakah anda sering menggunakan Auto Indent Ext...                                           1.000000
#
#                                                      Apakah anda sering menggunakan Extension berbayar?  \
# Seberapa sering anda menggunakan bahasa pemrogr...                                           0.955556
# Seberapa tahukah anda tentang bahasa permograma...                                          -0.155556
# Pernahkah anda membuat program menggunakan baha...                                           1.000000
# Seberapa tahukah anda tentang Pemrograman Inter...                                          -0.111111
# Seberapa tahukah anda tentang Pemrograman Beror...                                          -0.111111
# Seberapa sering anda menggunakan programming so...                                           0.955556
# Seberapa perlunya dokumen manual/tutorial ketik...                                          -0.244444
# Pernakah anda melakukan trial dan error atau me...                                           0.911111
# Seberapa seringkah anda menggunakan Extension s...                                           0.955556
# Seberapa sering anda mengelola (menginstal,meng...                                           0.955556
#  Apakah anda sering menggunakan Extension berba...                                           1.000000
#  Apakah anda sering menggunakan Auto Indent Ext...                                           0.955556
#
#                                                      Apakah anda sering menggunakan Auto Indent Extension?
# Seberapa sering anda menggunakan bahasa pemrogr...                                           1.000000
# Seberapa tahukah anda tentang bahasa permograma...                                          -0.155556
# Pernahkah anda membuat program menggunakan baha...                                           0.955556
# Seberapa tahukah anda tentang Pemrograman Inter...                                          -0.111111
# Seberapa tahukah anda tentang Pemrograman Beror...                                          -0.111111
# Seberapa sering anda menggunakan programming so...                                           1.000000
# Seberapa perlunya dokumen manual/tutorial ketik...                                          -0.244444
# Pernakah anda melakukan trial dan error atau me...                                           0.955556
# Seberapa seringkah anda menggunakan Extension s...                                           1.000000
# Seberapa sering anda mengelola (menginstal,meng...                                           1.000000
#  Apakah anda sering menggunakan Extension berba...                                           0.955556
#  Apakah anda sering menggunakan Auto Indent Ext...                                           1.000000

# %% [markdown]
# ## Colerration Map

# %%
f, ax = plt.subplots(figsize=(25,20))
sns.heatmap(correlations, annot=True, linewidths=.4, fmt='.3f')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
